# %%
import os
import shutil
import subprocess

def get_files_recursively(start_directory, filter_extension=None):
    for root, _, files in os.walk(start_directory):
        for file in files:
            if filter_extension is None or file.lower().endswith(filter_extension):
                yield os.path.join(root, file)

def selective_copy(source, file_extension=None):
    for file in get_files_recursively(source, file_extension):
        d = file.split('/')
        s = file.split(' ')
        try:
          path = "/content/drive/My\ Drive/ADNI_C/superTest/"+d[5]+"/"
          print(d)
#           print(s[0]+"\ "+s[1])
#           os.mkdir(path)
#           shutil.copy(file, path)
#           newfile = s[0]+"\ "+s[1]
#           myCmd = "med2image -i "+ newfile +" -d "+ path + " -o image.jpg -s -1"
#           myCmd = 'med2image -i ' + src + ' -d /content/drive/My\ Drive/ADNI_C/test/002_S_0413/ -o image.jpg -s -1'
#           os.system(myCmd)
#           print("The following file has been copied to", path)
        except:
            pass
if __name__ == "__main__":
    selective_copy("/content/drive/My Drive/ADNI_C/",
                   ".nii")
# Out:
# ['', 'content', 'drive', 'My Drive', 'ADNI_C', 'b.nii']
# ['', 'content', 'drive', 'My Drive', 'ADNI_C', '027_S_0835', 'ADNI_027_S_0835_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20071115094836333_S40013_I82223.nii']
# ['', 'content', 'drive', 'My Drive', 'ADNI_C', '027_S_0835', 'MPR__GradWarp__B1_Correction__N3__Scaled', '2006-09-28_09_23_19.0', 'S19496', 'ADNI_027_S_0835_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20070109231952406_S19496_I35653.nii']
# ['', 'content', 'drive', 'My Drive', 'ADNI_C', '127_S_0260', 'ADNI_127_S_0260_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20080522163149690_S50016_I106542.nii']
# ['', 'content', 'drive', 'My Drive', 'ADNI_C', '127_S_0260', 'MPR__GradWarp__B1_Correction__N3__Scaled', '2006-05-01_13_12_05.0', 'S13858', 'ADNI_127_S_0260_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20061227143400735_S13858_I34371.nii']
# ...

# %%
print("a")
# Out:
# a

# %%
import subprocess
subprocess.run(["med2image","-i /content/sample_data/b.nii -d /content/sample_data/ -o image.jpg -s -1"])
# subprocess.run(["med2image", "-i /content/drive/My\ Drive/ADNI_C/002_S_0413/ADNI_002_S_0413_MR_MPR____N3__Scaled_2_Br_20081001114937668_S14782_I118675.nii -d /content/drive/My\ Drive/ADNI_C/test/alien/ -o image.jpg -s -1"], universal_newlines=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
# Out:
# CompletedProcess(args=['med2image', '-i /content/sample_data/b.nii -d /content/sample_data/ -o image.jpg -s -1'], returncode=1)

# %%
import subprocess

src = "/content/drive/My Drive/ADNI_C/test/002_S_0413/ADNI_002_S_0413_MR_MPR____N3__Scaled_Br_20070804124954957_S32945_I64551.nii"
path = "-i "+src+" -d /content/drive/My Drive/ADNI_C/test/002_S_0413/ -o image.jpg -s -1"
test = "-v"
type(path)
subprocess.run(["med2image", path])
# !med2image -i src -d/content/drive/My\ Drive/ADNI_C/test/002_S_0413 -o image.jpg -s -1
# Out:
# CompletedProcess(args=['med2image', '-i /content/drive/My Drive/ADNI_C/test/002_S_0413/ADNI_002_S_0413_MR_MPR____N3__Scaled_Br_20070804124954957_S32945_I64551.nii -d /content/drive/My Drive/ADNI_C/test/002_S_0413/ -o image.jpg -s -1'], returncode=1)

# %%
import shutil

shutil.copy("/content/drive/My Drive/ADNI_C/b.nii", "/content/sample_data")
# Out:
# '/content/sample_data/b.nii'

# %%
import os

def get_files_recursively(start_directory, filter_extension=None):
    for root, _, files in os.walk(start_directory):
        for file in files:
            if filter_extension is None or file.lower().endswith(filter_extension):
                yield os.path.join(root, file)

def selective_copy(source, file_extension=None):
    for file in get_files_recursively(source, file_extension):

        d = file.split('/')
        # !med2image -i /content/drive/My\ Drive/ADNI_C/test/002_S_0729/ADNI_002_S_0729_MR_MPR____N3__Scaled_Br_20081027115509985_S56800_I124008.nii -d /content/drive/My\ Drive/ADNI_C/test/002_S_0729 -o image.jpg -s -1
        try:
          path = "/content/drive/My Drive/ADNI_C/test/"+d[5]+"/"

        except:

            pass
if __name__ == "__main__":
    selective_copy("/content/drive/My Drive/ADNI_C/",
                   ".nii")

# %%
import os
src = "/content/drive/My\ Drive/ADNI_C/test/002_S_0413/ADNI_002_S_0413_MR_MPR____N3__Scaled_Br_20070804124954957_S32945_I64551.nii"
myCmd = 'med2image -i ' + src + ' -d /content/drive/My\ Drive/ADNI_C/test/002_S_0413/ -o image.jpg -s -1'
os.system(myCmd)
# Out:
# 0

# %%
try:
    from urllib.request import urlretrieve
except ImportError:
    from urllib import urlretrieve

urlretrieve('http://example.org', 'outfile.dat')
# Out:
# ('outfile.dat', <http.client.HTTPMessage at 0x7fd64cb0ddd8>)
