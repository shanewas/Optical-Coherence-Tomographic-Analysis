# %%
# import os
# import shutil
# import pandas as pd
# import glob
# from shutil import copyfile
# data = pd.read_csv('/content/drive/My Drive/ADNI_C/test/adni.csv')

# %%
names = data.iloc[:,1]
labels = data.iloc[:,2]

# %%
source = os.listdir("/content/drive/My Drive/ADNI_C/test")
destination = "/content/drive/My Drive/ADNI_C/test/des"

# %%
labels

# %%
///!!!!!!!!!!!!!!!!!!!!!!!!warning !!!!!!!!!!!!!!!!!!!!!
i=0
path = "/content/drive/My Drive/ADNI_C/test"
des = "/content/drive/My Drive/ADNI_C/test/des"
while i < len(names):
    path2 = path + "/" + names[i]
    finaldes = des+"/"+labels[i]
    try:
#         shutil.move(path2,finaldes)
    except:
        pass
    print(path2)
    print(finaldes)
    i = i+1

# %%
data = glob.glob("/content/drive/My Drive/ADNI_C/test/des/AD/*")

# %%
# print(data)
# a = data[0].split('/')
# a[8]
# path = "/content/drive/My Drive/ADNI_C/test/des/AD/" + a[8]
# type(path)
# Out:
# ['/content/drive/My Drive/ADNI_C/test/des/AD/002_S_1018', '/content/drive/My Drive/ADNI_C/test/des/AD/012_S_0689', '/content/drive/My Drive/ADNI_C/test/des/AD/027_S_0404', '/content/drive/My Drive/ADNI_C/test/des/AD/130_S_0956', '/content/drive/My Drive/ADNI_C/test/des/AD/ADNI_116_S_0487_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20080617165712709_S51211_I109893.nii', '/content/drive/My Drive/ADNI_C/test/des/AD/136_S_0300', '/content/drive/My Drive/ADNI_C/test/des/AD/027_S_1081', '/content/drive/My Drive/ADNI_C/test/des/AD/027_S_1385', '/content/drive/My Drive/ADNI_C/test/des/AD/031_S_1209', '/content/drive/My Drive/ADNI_C/test/des/AD/027_S_1082', '/content/drive/My Drive/ADNI_C/test/des/AD/018_S_0335', '/content/drive/My Drive/ADNI_C/test/des/AD/018_S_0633', '/content/drive/My Drive/ADNI_C/test/des/AD/023_S_0916', '/content/drive/My Drive/ADNI_C/test/des/AD/005_S_0814', '/content/drive/My Drive/ADNI_C/test/des/AD/136_S_0426', '/content/drive/My Drive/ADNI_C/test/des/AD/023_S_126
# ...

# %%
os.walk("/content/drive/My Drive/ADNI_C/test/des/ADOUT/")
# Out:
# <generator object walk at 0x7f595a78afc0>

# %%
i = 0
j = 0
while i < len(data):
  path = "/content/drive/My Drive/ADNI_C/test/des/ADOUT/"
  data1 = glob.glob(data[i]+"/*")
#   print(data1)
  for test in data1:
    base, extension = os.path.splitext(test)
    new_name = str(j)+extension
#     print(new_name)
    potato = test.split('/')
#     print(potato[9])
    new_src = path + potato[9]
    new_path = path + new_name
#     print(new_src)
    j = j+1
    shutil.copy(test, path)
    os.rename(new_src, new_path)
#   print(data[i])
#   shutil.copyfile(data[i]+"/*",path)
  i = i + 1
#   data1 = glob.glob()
#   print(data1)
#   shutil.copy(data[i],)

# %%
i = 0
while i < len(data):
  source = "/content/drive/My Drive/ADNI_C/test/des/AD/" + a[8]
  destination = "/content/drive/My Drive/ADNI_C/test/des/ADOUT/"
#   old_name = os.path.join( os.path.abspath(destination), source )

  # Separate base from extension
  base, extension = os.path.splitext(source)

  # Initial new name
#   new_name = os.path.join("/content/drive/My Drive/ADNI_C/test/des/AD/", base, source)
  new_name = str(i)+extension
#   a = data[i].split('/')
  print(new_name)
#   a[8]
#   source = "/content/drive/My Drive/ADNI_C/test/des/AD/" + a[8]
#   type(path)
#   data1 = glob.glob(data[i]+"/*")
#   print(data1)
#   for test in data1:
#     print(test)
#     shutil.copy(test, path)
#   print(data[i])
#   shutil.copyfile(data[i]+"/*",path)
  i = i + 1
#   data1 = glob.glob()
#   print(data1)
#   shutil.copy(data[i],)

# %%
i = 0
while i < len(data):
  destination = "/content/drive/My Drive/ADNI_C/test/des/ADOUT/"
  a = data[i].split('/')
#   print(a)
#   a[8]
  source = "/content/drive/My Drive/ADNI_C/test/des/AD/" + a[8]
#   type(path)
#   data1 = glob.glob(data[i]+"/*")
#   print(destination)
#   for test in data1:
#     print(test)
  shutil.copy(test, path)
  
#   print(data[i])
#   shutil.copyfile(data[i]+"/*",path)
  i = i + 1
#   data1 = glob.glob()
#   print(data1)
#   shutil.copy(data[i],)
