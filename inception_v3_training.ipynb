# %%
import os
import shutil
import pandas as pd
import glob
from shutil import copyfile

# %%
data = glob.glob("/content/drive/My Drive/ADNI_C/test/des/ADtrain/*.jpg")
data1 = glob.glob("/content/drive/My Drive/ADNI_C/test/des/ADtrain/AD/*.jpg")

# %%
data_cn = glob.glob("/content/drive/My Drive/ADNI_C/test/des/ADtrain/*.jpg")
data_cn1 = glob.glob("/content/drive/My Drive/ADNI_C/test/des/ADtrain/AD/*.jpg")

# %%
#!!!!!!for AD
# des = "/content/drive/My Drive/ADNI_C/test/des/ADtrain/AD"
# for hold in data:
#   shutil.move(hold,des)

# %%
print(len(data))
print(len(data1))
# Out:
# 0
# 2260

# %%
#!!!!!!!!AD
# i =0
# src = "/content/drive/My Drive/ADNI_C/test/des/ADOUT"
# train = "/content/drive/My Drive/ADNI_C/test/des/ADtrain"
# test = "/content/drive/My Drive/ADNI_C/test/des/ADtest"
# for hold in data:
#   if i % 5 == 0:
#     shutil.copy(hold, test)
#   else:
#     shutil.copy(hold, train)
#   i = i + 1

# %%
trainCN = glob.glob("/content/drive/My Drive/ADNI_C/test/des/ADtrain/CN/*")
testCN = glob.glob("/content/drive/My Drive/ADNI_C/test/des/ADtest/CN/*")
trainAD = glob.glob("/content/drive/My Drive/ADNI_C/test/des/ADtrain/AD/*")
testAD = glob.glob("/content/drive/My Drive/ADNI_C/test/des/ADtest/AD/*")
trainMCI = glob.glob("/content/drive/My Drive/ADNI_C/test/des/ADtrain/MCI/*")
testMCI = glob.glob("/content/drive/My Drive/ADNI_C/test/des/ADtest/MCI/*")
print(len(trainCN))
print(len(testCN))
print(len(trainAD))
print(len(testAD))
print(len(trainMCI))
print(len(testMCI))
# Out:
# 4227
# 1057
# 2247
# 561
# 4718
# 1180
