# %%
import numpy as np
import matplotlib.pyplot as plt

# data to plot
n_groups = 2
means_frank = (0.9858, 0.9317)
means_guido = (0.9524, 0.8985)
means_guid = (0.75, 0.60)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.5

rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='VGG 19')

rects2 = plt.bar(index + bar_width, means_guido, bar_width,
alpha=opacity,
color='g',
label='Inception v3')

# rects4 = plt.bar(index + bar_width, means_guid, bar_width,
# alpha=opacity,
# color='r',
# label='ResNet')

plt.xlabel('Algorithms')
plt.ylabel('Accuracy')
plt.title('Scores by algorithm')
plt.xticks(index + bar_width, ('AD vs CN', 'AD vs CN vs MCI'))
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# data to plot
n_groups = 2
means_frank = (0.9858, 0.9317)
means_guido = (0.9524, 0.8985)
means_guid = (0.7539, 0.6165)


# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.5

rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='VGG19')

rects2 = plt.bar(index + bar_width, means_guido, bar_width,
alpha=opacity,
color='g',
label='Inception v3')

rects3 = plt.bar(index + 2*bar_width, means_guid, bar_width,
alpha=opacity,
color='orange',
label='Resnet')

plt.xlabel('Algorithms')
plt.ylabel('Accuracy')
plt.title('Scores by algorithm')
plt.xticks(index + bar_width, ('AD vs CN', 'AD vs CN vs MCI'))
# plt.legend()
plt.legend(loc = 'upper right', fontsize = 9)

plt.tight_layout()
plt.show()

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('/content/drive/My Drive/ADNI_C/test/des/ADtrain/AD/1066.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt

acc = [0.4021,0.4545,0.5365,0.6395,0.6920
        ,0.7665,0.8070,0.8305,0.8514,0.8490
        ,0.8870,0.8880,0.8986,0.9075,0.9135
        ,0.9195,0.9255,0.9242,0.9420,0.9415
      ]
loss = [1.1666,1.0561,0.9514,0.7884,0.7884
        ,0.5092,0.4342,0.3990,0.3528,0.3380
        ,0.2578,0.2580,0.2497,0.2213,0.1979
        ,0.1960,0.1767,0.1868,0.1379,0.1503
       ]


# Get it for the validation-set (we only use the test-set).
val_acc = [0.4503,0.5490,0.5915,0.7062,0.7863
           ,0.8081,0.8499,0.8352,0.8749,0.8981
           ,0.9114,0.9174,0.9192,0.9196,0.9317
           ,0.9346,0.9400,0.9510,0.9482,0.9582]
val_loss = [1.1220,0.9240,0.8372,0.6645,0.4902
            ,0.4288,0.3524,0.3641,0.2888,0.2304
            ,0.2092,0.1966,0.1869,0.1858,0.1677
            ,0.1515,0.1430,0.1315,0.1217,0.1124]



# Plot the accuracy and loss-values for the training-set.
plt.plot(acc, linestyle='-', color='b', label='Training Acc.')
plt.plot(loss, 'o', color='b', label='Training Loss')

# Plot it for the test-set.
plt.plot(val_acc, linestyle='--', color='r', label='Test Acc.')
plt.plot(val_loss, 'o', color='r', label='Test Loss')

# Plot title and legend.
plt.title('Training and Test Accuracy')
plt.legend()

# Ensure the plot shows correctly.
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# xfer_acc = transfer_learning_history.history['acc']
# val_acc = transfer_learning_history.history['val_acc']
# xfer_loss = transfer_learning_history.history['loss']
# val_loss = transfer_learning_history.history['val_loss']
xfer_acc = [0.4021,0.4545,0.5365,0.6395,0.6920
        ,0.7665,0.8070,0.8305,0.8514,0.8490
        ,0.8870,0.8880,0.8986,0.9075,0.9135
        ,0.9195,0.9255,0.9242,0.9420,0.9415
      ]
xfer_loss = [1.1666,1.0561,0.9514,0.7884,0.7884
        ,0.5092,0.4342,0.3990,0.3528,0.3380
        ,0.2578,0.2580,0.2497,0.2213,0.1979
        ,0.1960,0.1767,0.1868,0.1379,0.1503
       ]

val_acc = [0.4503,0.5490,0.5915,0.7062,0.7863
           ,0.8081,0.8499,0.8352,0.8749,0.8981
           ,0.9114,0.9174,0.9192,0.9196,0.9317
           ,0.9346,0.9400,0.9510,0.9482,0.9582]
val_loss = [1.1220,0.9240,0.8372,0.6645,0.4902
            ,0.4288,0.3524,0.3641,0.2888,0.2304
            ,0.2092,0.1966,0.1869,0.1858,0.1677
            ,0.1515,0.1430,0.1315,0.1217,0.1124]
epochs = range(len(xfer_acc))

x = np.array(epochs)
y = np.array(xfer_acc)
x_smooth = np.linspace(x.min(), x.max(), 500)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, 'r-', label = 'Training')

x1 = np.array(epochs)
y1 = np.array(val_acc)
x1_smooth = np.linspace(x1.min(), x1.max(), 500)
y1_smooth = spline(x1, y1, x1_smooth)

plt.plot(x1_smooth, y1_smooth, 'g-', label = 'Validation')
plt.title('Transfer Learning - Training and Validation Accuracy')
plt.legend(loc = 'lower left', fontsize = 9)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim(0,1.05)

plt.figure()
x = np.array(epochs)
y = np.array(xfer_loss)
x_smooth = np.linspace(x.min(), x.max(), 500)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, 'r-', label = 'Training')

x1 = np.array(epochs)
y1 = np.array(val_loss)
x1_smooth = np.linspace(x1.min(), x1.max(), 500)
y1_smooth = spline(x1, y1, x1_smooth)

plt.plot(x1_smooth, y1_smooth, 'g-', label = 'Validation')
plt.title('Transfer Learning - Training and Validation Loss')
plt.legend(loc = 'upper right', fontsize = 9)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim(0,max(y1))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-bea540bed0c7> in <module>()
#      30 y = np.array(xfer_acc)
#      31 x_smooth = np.linspace(x.min(), x.max(), 500)
# ---> 32 y_smooth = spline(x, y, x_smooth)
#      33 plt.plot(x_smooth, y_smooth, 'r-', label = 'Training')
#      34
#
# NameError: name 'spline' is not defined

# %%
acc = [0.4021,0.4545,0.5365,0.6395,0.6920
        ,0.7665,0.8070,0.8305,0.8514,0.8490
        ,0.8870,0.8880,0.8986,0.9075,0.9135
        ,0.9195,0.9255,0.9242,0.9420,0.9415
      ]
loss = [1.1666,1.0561,0.9514,0.7884,0.7884
        ,0.5092,0.4342,0.3990,0.3528,0.3380
        ,0.2578,0.2580,0.2497,0.2213,0.1979
        ,0.1960,0.1767,0.1868,0.1379,0.1503
       ]

# Get it for the validation-set (we only use the test-set).
val_acc = [0.4503,0.5490,0.5915,0.7062,0.7863
           ,0.8081,0.8499,0.8352,0.8749,0.8981
           ,0.9114,0.9174,0.9192,0.9196,0.9317
           ,0.9346,0.9400,0.9510,0.9482,0.9582]
val_loss = [1.1220,0.9240,0.8372,0.6645,0.4902
            ,0.4288,0.3524,0.3641,0.2888,0.2304
            ,0.2092,0.1966,0.1869,0.1858,0.1677
            ,0.1515,0.1430,0.1315,0.1217,0.1124]
history = [acc, loss, val_acc, val_loss]
print (history[1])
# Out:
# [1.1666, 1.0561, 0.9514, 0.7884, 0.7884, 0.5092, 0.4342, 0.399, 0.3528, 0.338, 0.2578, 0.258, 0.2497, 0.2213, 0.1979, 0.196, 0.1767, 0.1868, 0.1379, 0.1503]

# %%
# summarize history for accuracy
plt.plot(history[0])
plt.plot(history[2])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history[1])
plt.plot(history[3])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('/content/drive/My Drive/ADNI_C/adni.csv')
df.head()

# fig = px.line(df, x = 'Group', y = 'Age', title='MRI Group vs Age')
# fig.show()
# Out:
#    Image Data ID     Subject Group Sex  ...       Type   Acq Date Format Downloaded
# 0         120562  126_S_0605    CN   F  ...  Processed  6/30/2008  NiFTI  7/23/2019
# 1          38878  126_S_0605    CN   F  ...  Processed  6/29/2006  NiFTI  7/23/2019
# 2         138011  023_S_1046   MCI   M  ...  Processed  1/21/2009  NiFTI  7/23/2019
# 3          59677  116_S_0487    AD   M  ...  Processed  8/10/2006  NiFTI  7/23/2019
# 4          71451  018_S_0633    AD   M  ...  Processed  7/17/2007  NiFTI  7/23/2019
#
# [5 rows x 12 columns]

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('/content/drive/My Drive/ADNI_C/adni.csv')
df.head()

fig = px.line(df, x = 'Group', y = 'Sex', title='MRI Group vs Age')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e7631d76-e2e6-45ce-94ea-812668d20a0f" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e7631d76-e2e6-45ce-94ea-812668d20a0f")) {
#                     Plotly.newPlot(
#                         'e7631d76-e2e6-45ce-94ea-812668d20a0f',
# ...

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('/content/drive/My Drive/ADNI_C/adni.csv')
df.head()

fig = px.line(df, x = 'Group', y = 'Age', title='MRI Group vs Age')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-42-d6d3cec48660> in <module>()
#       1 import pandas as pd
# ----> 2 import plotly.express as px
#       3
#       4 df = pd.read_csv('/content/drive/My Drive/ADNI_C/adni.csv')
#       5 df.head()
#
# ModuleNotFoundError: No module named 'plotly.express'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
fig = px.bar(df, x='Group', y='Age', color='Sex', height=400,width=400)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-cfbf9887bd09> in <module>()
# ----> 1 fig = px.bar(df, x='Group', y='Age', color='Sex', height=400,width=400)
#       2 fig.show()
#
# NameError: name 'px' is not defined

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/ADNI_C/adni.csv')
import plotly.express as px
fig = px.histogram(df, x="Age")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-43-f888e1acf34b> in <module>()
#       2 import pandas as pd
#       3 df = pd.read_csv('/content/drive/My Drive/ADNI_C/adni.csv')
# ----> 4 import plotly.express as px
#       5 fig = px.histogram(df, x="Age")
#       6 fig.show()
#
# ModuleNotFoundError: No module named 'plotly.express'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/ADNI_C/adni.csv')
import plotly.express as px
fig = px.histogram(df, x="Group")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="eeddb509-8727-43cb-b0a7-c44d28eb1679" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("eeddb509-8727-43cb-b0a7-c44d28eb1679")) {
#                     Plotly.newPlot(
#                         'eeddb509-8727-43cb-b0a7-c44d28eb1679',
# ...

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/ADNI_C/adni.csv')
import plotly.express as plt
fig = plt.histogram(df, x="Sex")
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-87c0cfe4c685> in <module>()
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 df = pd.read_csv('/content/drive/My Drive/ADNI_C/adni.csv')
#       4 import plotly.express as plt
#       5 fig = plt.histogram(df, x="Sex")
#
# ...

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/ADNI_C/adni.csv')
import plotly.express as px
fig = px.histogram(df, x="Acq Date")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-44-e6d90701ffae> in <module>()
#       2 import pandas as pd
#       3 df = pd.read_csv('/content/drive/My Drive/ADNI_C/adni.csv')
# ----> 4 import plotly.express as px
#       5 fig = px.histogram(df, x="Acq Date",width=10)
#       6 fig.show()
#
# ModuleNotFoundError: No module named 'plotly.express'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
